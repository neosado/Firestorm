# %%
using Reactive, Interact
using DataStructures

include("ScenarioOneIJUtil.jl")
# Out:
# <script charset="utf-8">(function ($, undefined) {
#
#     function createElem(tag, attr, content) {
# 	// TODO: remove jQuery dependency
# 	var el = $("<" + tag + "/>").attr(attr);
# 	if (content) {
# 	    el.append(content);
# 	}
# 	return el[0];
#     }
#
#     // A widget must expose an id field which identifies it to the backend,
#     // an elem attribute which is will be added to the DOM, and
#     // a getState() method which returns the value to be sent to the backend
#     // a sendUpdate() method which sends its current value to the backend
#     var Widget = {
# 	id: undefined,
# 	elem: undefined,
# 	label: undefined,
# 	getState: function () {
# 	    return this.elem.value;
# 	},
# 	sendUpdate: undefined
#     };
#
#     var Slider = function (typ, id, init) {
# 	var attr = { type:  "range",
# 		     value: init.value,
# 		     min:   init.min,
# 		     max:   init.max,
# 		     step:  init.step },
# 	    elem = createElem("input", attr),
# 	    self = this;
#
# ...

# %% [markdown]
# # ScenarioOne v0.3

# %%
timestamp = 1423111126
datafile = "datafiles/s1results_v0_3.jld.$timestamp";

# %%
f = figure(facecolor = "white")
@manipulate for param_set = togglebuttons(OrderedDict(["1", "2"], [1, 2]), label = "param set"), policy = [:stay, :back, :landing, :lower], r_surveillance = slider(0.:0.5:1., value = 0., label = "sv. reward"); withfig(f) do
        plotEvaluation(param_set, policy, fig = f, datafile = datafile, sim_continue = true, r_surveillance = r_surveillance)
    end
end
# Out:
# Options{:ToggleButtons,Int64}([Input{Int64}] 1,"param set",1,"1",["1"=>1,"2"=>2])
# Options{:ToggleButtons,Symbol}([Input{Symbol}] stay,"policy",:stay,"stay",["stay"=>:stay,"back"=>:back,"landing"=>:landing,"lower"=>:lower])
# Slider{Float64}([Input{Float64}] 0.0,"sv. reward",0.0,0.0:0.5:1.0)
# Figure(PyObject <matplotlib.figure.Figure object at 0x114bfb390>)

# %%
f = figure(facecolor = "white")
@manipulate for param_set = togglebuttons(OrderedDict(["1", "2"], [1, 2]), label = "param set"), r_surveillance = slider(0.:0.5:1., value = 0., label = "sv. reward"); withfig(f) do
        plotPolicy(param_set, fig = f, datafile = datafile, sim_continue = true, r_surveillance = r_surveillance)
    end
end
# Out:
# Options{:ToggleButtons,Int64}([Input{Int64}] 1,"param set",1,"1",["1"=>1,"2"=>2])
# Slider{Float64}([Input{Float64}] 0.0,"sv. reward",0.0,0.0:0.5:1.0)
# Figure(PyObject <matplotlib.figure.Figure object at 0x1165294d0>)

# %% [markdown]
# # Debug

# %%
if false
    PM, U, RE, N, params = plotPolicy(1, draw = false, datafile = datafile, sim_continue = true, r_surveillance = 1.)
    println(PM)
    println(U[:stay])
    println(U[:back])
    println(U[:landing])
    println(U[:lower])
end

# %%
if false
    param_set = 1
    policy = :stay

    for r_surveillance in [0., 1., 2.]
        plotEvaluation(param_set, policy, draw = false, datafile = datafile, sim_continue = true, r_surveillance = r_surveillance)
        savefig("eval_" * string(param_set) * "_" * string(policy) * "_" * string(int(r_surveillance)) * ".png")
    end
end

# %%
if false
    param_set = 1

    for r_surveillance in [0., 1., 2.]
        plotPolicy(param_set, draw = false, datafile = datafile, sim_continue = true, r_surveillance = r_surveillance)
        savefig("policy_" * string(param_set) * "_" * string(int(r_surveillance)) * ".png")
    end
end

# %% [markdown]
# # ScenarioOne v0.2.1

# %%
timestamp = 1423161119
datafile = "datafiles/s1results_v0_2_1.jld.$timestamp";

# %%
f = figure(facecolor = "white")
@manipulate for param_set = togglebuttons(OrderedDict(["1", "2"], [1, 2]), label = "param set"), policy = [:back, :landing, :stay, :lower], sim_comm_loss_duration_sigma = togglebuttons(OrderedDict(["1.", "2.", "5."], [1., 2., 5.]), label = "sigma"); withfig(f) do
        plotEvaluation(param_set, policy, fig = f, datafile = datafile, sim_comm_loss_duration_mu = 10., sim_comm_loss_duration_sigma = sim_comm_loss_duration_sigma)
    end
end
# Out:
# Options{:ToggleButtons,Int64}([Input{Int64}] 1,"param set",1,"1",["1"=>1,"2"=>2])
# Options{:ToggleButtons,Symbol}([Input{Symbol}] back,"policy",:back,"back",["back"=>:back,"landing"=>:landing,"stay"=>:stay,"lower"=>:lower])
# Options{:ToggleButtons,Float64}([Input{Float64}] 1.0,"sigma",1.0,"1.",["1."=>1.0,"2."=>2.0,"5."=>5.0])
# Figure(PyObject <matplotlib.figure.Figure object at 0x1168f1910>)

# %%
f = figure(facecolor = "white")
@manipulate for param_set = togglebuttons(OrderedDict(["1", "2"], [1, 2]), label = "param set"), sim_comm_loss_duration_sigma = togglebuttons(OrderedDict(["1.", "2.", "5."], [1., 2., 5.]), label = "sigma"); withfig(f) do
        plotPolicy(param_set, fig = f, datafile = datafile, sim_comm_loss_duration_mu = 10., sim_comm_loss_duration_sigma = sim_comm_loss_duration_sigma)
    end
end
# Out:
# Options{:ToggleButtons,Int64}([Input{Int64}] 1,"param set",1,"1",["1"=>1,"2"=>2])
# Options{:ToggleButtons,Float64}([Input{Float64}] 1.0,"sigma",1.0,"1.",["1."=>1.0,"2."=>2.0,"5."=>5.0])
# Figure(PyObject <matplotlib.figure.Figure object at 0x11653ded0>)

# %% [markdown]
# # ScenarioOne v0.2

# %%
timestamp = 1423164658
datafile = "datafiles/s1results_v0_2.jld.$timestamp";

# %%
f = figure(facecolor = "white")
@manipulate for param_set = togglebuttons(OrderedDict(["1", "2"], [1, 2]), label = "param set"), policy = [:back, :landing, :stay, :lower], sim_comm_loss_duration_mu = slider(5.:5.:15., value = 5., label = "duration"); withfig(f) do
        plotEvaluation(param_set, policy, fig = f, datafile = datafile, sim_comm_loss_duration_mu = sim_comm_loss_duration_mu)
    end
end
# Out:
# Options{:ToggleButtons,Int64}([Input{Int64}] 1,"param set",1,"1",["1"=>1,"2"=>2])
# Options{:ToggleButtons,Symbol}([Input{Symbol}] back,"policy",:back,"back",["back"=>:back,"landing"=>:landing,"stay"=>:stay,"lower"=>:lower])
# Slider{Float64}([Input{Float64}] 5.0,"duration",5.0,5.0:5.0:15.0)
# Figure(PyObject <matplotlib.figure.Figure object at 0x117061210>)

# %%
f = figure(facecolor = "white")
@manipulate for param_set = togglebuttons(OrderedDict(["1", "2"], [1, 2]), label = "param set"), sim_comm_loss_duration_mu = slider(5.:5.:15., value = 5., label = "duration"); withfig(f) do
        plotPolicy(param_set, fig = f, datafile = datafile, sim_comm_loss_duration_mu = sim_comm_loss_duration_mu)
    end
end
# Out:
# Options{:ToggleButtons,Int64}([Input{Int64}] 1,"param set",1,"1",["1"=>1,"2"=>2])
# Slider{Float64}([Input{Float64}] 5.0,"duration",5.0,5.0:5.0:15.0)
# Figure(PyObject <matplotlib.figure.Figure object at 0x117b5f250>)

# %% [markdown]
# # Debug

# %%
if false
    PM, U, RE, N, params = plotPolicy(1, draw = false, datafile = datafile, sim_comm_loss_duration_mu = 5.)
    println(PM)
    println(U[:stay])
    println(U[:back])
    println(U[:landing])
    println(U[:lower])
end

# %%
if false
    param_set = 1
    policy = :stay

    for sim_comm_loss_duration_mu in [5., 10., 15.]
        plotEvaluation(param_set, policy, draw = false, datafile = datafile, sim_comm_loss_duration_mu = sim_comm_loss_duration_mu)
        savefig("eval_" * string(param_set) * "_" * string(policy) * "_" * string(int(sim_comm_loss_duration_mu)) * ".png")
    end
end

# %%
if false
    param_set = 1

    for sim_comm_loss_duration_mu in [5., 10., 15.]
        plotPolicy(param_set, draw = false, datafile = datafile, sim_comm_loss_duration_mu = sim_comm_loss_duration_mu)
        savefig("policy_" * string(param_set) * "_" * string(int(sim_comm_loss_duration_mu)) * ".png")
    end
end

# %% [markdown]
# # ScenarioOne v0.1

# %%
timestamp = 1423158940
datafile = "datafiles/s1results_v0_1.jld.$timestamp";

# %%
f = figure(facecolor = "white")
@manipulate for param_set = togglebuttons(OrderedDict(["1", "2"], [1, 2]), label = "param set"), policy = [:back, :landing, :stay], aircraft_traj_uncertainty = slider(0.:1.:2., value = 0., label = "uncertainty"); withfig(f) do
        plotEvaluation(param_set, policy, fig = f, datafile = datafile, aircraft_traj_uncertainty = aircraft_traj_uncertainty)
    end
end
# Out:
# Options{:ToggleButtons,Int64}([Input{Int64}] 1,"param set",1,"1",["1"=>1,"2"=>2])
# Options{:ToggleButtons,Symbol}([Input{Symbol}] back,"policy",:back,"back",["back"=>:back,"landing"=>:landing,"stay"=>:stay])
# Slider{Float64}([Input{Float64}] 0.0,"uncertainty",0.0,0.0:1.0:2.0)
# Figure(PyObject <matplotlib.figure.Figure object at 0x117b5f050>)

# %%
f = figure(facecolor = "white")
@manipulate for param_set = togglebuttons(OrderedDict(["1", "2"], [1, 2]), label = "param set"), aircraft_traj_uncertainty = slider(0.:1.:2., value = 0., label = "uncertainty"); withfig(f) do
        plotPolicy(param_set, fig = f, datafile = datafile, aircraft_traj_uncertainty = aircraft_traj_uncertainty)
    end
end
# Out:
# Options{:ToggleButtons,Int64}([Input{Int64}] 1,"param set",1,"1",["1"=>1,"2"=>2])
# Slider{Float64}([Input{Float64}] 0.0,"uncertainty",0.0,0.0:1.0:2.0)
# Figure(PyObject <matplotlib.figure.Figure object at 0x118758850>)

# %% [markdown]
# # Debug

# %%
if false
    PM, U, RE, N, params = plotPolicy(1, draw = false, datafile = datafile, aircraft_traj_uncertainty = 0.)
    println(PM)
    println(U[:stay])
    println(U[:back])
    println(U[:landing])
end

# %%
if false
    param_set = 1
    policy = :stay

    for aircraft_traj_uncertainty in [0., 1., 2.]
        plotEvaluation(param_set, policy, draw = false, datafile = datafile, aircraft_traj_uncertainty = aircraft_traj_uncertainty)
        savefig("eval_" * string(param_set) * "_" * string(policy) * "_" * string(int(aircraft_traj_uncertainty)) * ".png")
    end
end

# %%
if false
    param_set = 1

    for aircraft_traj_uncertainty in [0., 1., 2.]
        plotPolicy(param_set, draw = false, datafile = datafile, aircraft_traj_uncertainty = aircraft_traj_uncertainty)
        savefig("policy_" * string(param_set) * "_" * string(int(aircraft_traj_uncertainty)) * ".png")
    end
end
