# %%
using PyPlot

dist = 0:10

plot(dist, exp(-dist/20))
legend(["e", "2"])

n = 4
dist = norm([n, n] - [1, 1])
println(dist)
println(0.5 + 0.5 * exp(-dist/20))
# Out:
# 4.
# 242640687119286
# 0.904428946742359
# Figure(PyObject <matplotlib.figure.Figure object at 0x11f60fa50>)
